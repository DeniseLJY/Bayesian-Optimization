# %%
import numpy as np
# 导入数据
# EI
plot_ei_y1 = -1 * np.array([-1.62398831, -1.62398831, -0.48946707, -0.38359333, -0.38359333,
       -0.38359333, -0.38359333, -0.38359333, -0.38359333, -0.38359333,
       -0.38359333, -0.38359333, -0.38359333, -0.38359333, -0.38359333,
       -0.38359333])

plot_ei_y2 = -1 * np.array([-1.61906485, -1.61906485, -1.34190161, -1.34190161, -0.97197405,
       -0.47194027, -0.42376176, -0.36113731, -0.36113731, -0.32911325,
       -0.32911325, -0.32911325, -0.32911325, -0.32911325, -0.32911325,
       -0.32911325])

plot_ei_y3 = -1 * np.array([-1.72817481, -1.72817481, -1.72817481, -1.60390424, -1.60390424,
       -0.41407397, -0.41407397, -0.41407397, -0.38206314, -0.38206314,
       -0.38206314, -0.38206314, -0.38206314, -0.38206314, -0.38206314,
       -0.38206314])
plot_mei_y1 = -1 * np.array([-1.62949908, -0.66835069, -0.63809276, -0.42309189, -0.42309189,
       -0.39894242, -0.39894242, -0.39894242, -0.39894242, -0.39894242,
       -0.39894242, -0.39894242, -0.39894242, -0.39894242, -0.39894242,
       -0.39894242])
plot_mei_y2 = -1 * np.array([-1.71884361, -0.48329032, -0.46370451, -0.46370451, -0.46370451,
       -0.42998715, -0.42998715, -0.42998715, -0.42998715, -0.34506252,
       -0.32705879, -0.32705879, -0.32705879, -0.32705879, -0.32705879,
       -0.32705879])
plot_mei_y3 = -1 * np.array([-1.61806466, -1.61806466, -0.97597998, -0.97597998, -0.64430306,
       -0.25831937, -0.25831937, -0.25831937, -0.25831937, -0.25831937,
       -0.25831937, -0.25831937, -0.25831937, -0.25831937, -0.25831937,
       -0.25831937])

# %%
# PI
plot_pi_y1 = -1 * np.array([-1.62988321, -1.62988321, -1.1866121 , -1.02682658, -0.57080011,
       -0.51055889, -0.49729238, -0.48636715, -0.42832599, -0.42317066,
       -0.42317066, -0.3814056 , -0.3814056 , -0.3814056 , -0.3814056 ,
       -0.3814056 ])
plot_pi_y2 = -1 * np.array([-1.68024897, -1.67039666, -1.0029055 , -0.87687889, -0.79663568,
       -0.48714851, -0.48714851, -0.44784154, -0.44784154, -0.44784154,
       -0.44784154, -0.44784154, -0.44784154, -0.43808773, -0.37946999,
       -0.37946999])
plot_pi_y3 = -1 * np.array([-1.6226313 , -0.99964986, -0.62114924, -0.60200501, -0.42833618,
       -0.42833618, -0.39081387, -0.39081387, -0.39081387, -0.39081387,
       -0.39081387, -0.39081387, -0.39081387, -0.39081387, -0.39081387,
       -0.39081387])
plot_mpi_y1 = -1 * np.array([-1.63775808, -1.63775808, -1.63775808, -1.15581572, -1.15300042,
       -0.89463033, -0.69390562, -0.69390562, -0.67410921, -0.50677772,
       -0.50677772, -0.50239604, -0.50239604, -0.50239604, -0.4998832 ,
       -0.4998832 ])
plot_mpi_y2 = -1 * np.array([-1.60021089, -0.91952366, -0.91952366, -0.38367621, -0.38367621,
       -0.38367621, -0.37523087, -0.37523087, -0.37523087, -0.37492749,
       -0.37024272, -0.37024272, -0.37024272, -0.37024272, -0.37024272,
       -0.37024272])
plot_mpi_y3 = -1 * np.array([-1.62272108, -1.62272108, -1.35601325, -0.99626624, -0.39804751,
       -0.39804751, -0.39804751, -0.39804751, -0.37092606, -0.37092606,
       -0.24724049, -0.24724049, -0.24724049, -0.24724049, -0.24724049,
       -0.24724049])

# %%
# UCB
plot_ucb_y1 = -1 * np.array([-1.64506242, -0.99761342, -0.7772441 , -0.63983678, -0.52699724,
       -0.51213161, -0.4832348 , -0.467039  , -0.4338761 , -0.40757236,
       -0.40014323, -0.39770612, -0.39770612, -0.39770612, -0.39770612,
       -0.39770612])
plot_ucb_y2 = -1 * np.array([-1.55229223, -1.04038723, -0.77273231, -0.63697929, -0.5774581 ,
       -0.45277404, -0.45277404, -0.45277404, -0.36832907, -0.36832907,
       -0.36832907, -0.36832907, -0.36832907, -0.36832907, -0.36832907,
       -0.36832907])
plot_ucb_y3 = -1 * np.array([-1.81288718, -1.17061524, -0.66533056, -0.48686151, -0.44642944,
       -0.37915923, -0.37915923, -0.37915923, -0.37915923, -0.37915923,
       -0.37915923, -0.37915923, -0.37915923, -0.37915923, -0.37915923,
       -0.37915923])

# %%
# PES
plot_pes_y1= np.array([1.643029586787631,1.643029586787631,1.643029586787631,1.643029586787631,
                      1.643029586787631,0.6604625568356064,0.6604625568356064,0.6604625568356064,0.5699905229868153,
                      0.5699905229868153,0.5699905229868153,0.5699905229868153,0.5699905229868153,
                      0.5699905229868153,0.5699905229868153,0.5699905229868153])
plot_pes_y2= np.array([1.6673531293247237,1.6673531293247237,1.6673531293247237,0.9935383487615403,
                      0.9935383487615403,0.3786607319456121,0.3786607319456121,0.3786607319456121,
                      0.3786607319456121,0.3786607319456121,0.3786607319456121,0.3786607319456121,0.3786607319456121,
                      0.3786607319456121,0.3786607319456121,0.3786607319456121])
plot_pes_y3= np.array([1.6977575574960897,0.6059065931059533,0.6059065931059533,0.6059065931059533,
                     0.6059065931059533,0.6059065931059533,0.6059065931059533,0.6059065931059533,
                       0.6059065931059533,0.6059065931059533,0.6059065931059533,0.6059065931059533,
                       0.6059065931059533,0.6059065931059533,0.6059065931059533,0.6059065931059533])

# %%
#### Plot #######
import matplotlib.pyplot as plt

sample_index = np.array([5, 10, 15, 20, 25, 30, 35, 40, 45, 50, 55, 61, 62, 63, 64, 65])
plot_index = sample_index - 5

plt.title('Convergence plot (noise scale = 0.01)')
plt.xlabel('Number of iterations')
plt.ylabel('minf(x) after n iterations')

plt.plot(plot_index, plot_ei_y1, marker='o', markersize=3)
plt.plot(plot_index, plot_pi_y1, marker='o', markersize=3)
plt.plot(plot_index, plot_mei_y1, marker='o', markersize=3)
plt.plot(plot_index, plot_mpi_y1, marker='o', markersize=3)
plt.plot(plot_index, plot_ucb_y1, marker='o', markersize=3)
plt.plot(plot_index, plot_pes_y1, marker='o', markersize=3)

plt.legend(['EI', 'PI', 'Modified EI', 'Modified PI', 'UCB', 'PES'])
plt.show()

# %%
#### Plot #######
import matplotlib.pyplot as plt

sample_index = np.array([5, 10, 15, 20, 25, 30, 35, 40, 45, 50, 55, 61, 62, 63, 64, 65])
plot_index = sample_index - 5

plt.title('Convergence plot (noise scale = 0.05)')
plt.xlabel('Number of iterations')
plt.ylabel('minf(x) after n iterations')

plt.plot(plot_index, plot_ei_y2, marker='o', markersize=3)
plt.plot(plot_index, plot_pi_y2, marker='o', markersize=3)
plt.plot(plot_index, plot_mei_y2, marker='o', markersize=3)
plt.plot(plot_index, plot_mpi_y2, marker='o', markersize=3)
plt.plot(plot_index, plot_ucb_y2, marker='o', markersize=3)
plt.plot(plot_index, plot_pes_y2, marker='o', markersize=3)

plt.legend(['EI', 'PI', 'Modified EI', 'Modified PI', 'UCB', 'PES'])
plt.show()

# %%
#### Plot #######
import matplotlib.pyplot as plt

sample_index = np.array([5, 10, 15, 20, 25, 30, 35, 40, 45, 50, 55, 61, 62, 63, 64, 65])
plot_index = sample_index - 5

plt.title('Convergence plot (noise scale = 0.1)')
plt.xlabel('Number of iterations')
plt.ylabel('minf(x) after n iterations')

plt.plot(plot_index, plot_ei_y3, marker='o', markersize=3)
plt.plot(plot_index, plot_pi_y3, marker='o', markersize=3)
plt.plot(plot_index, plot_mei_y3, marker='o', markersize=3)
plt.plot(plot_index, plot_mpi_y3, marker='o', markersize=3)
plt.plot(plot_index, plot_ucb_y3, marker='o', markersize=3)
plt.plot(plot_index, plot_pes_y3, marker='o', markersize=3)

plt.legend(['EI', 'PI', 'Modified EI', 'Modified PI', 'UCB', 'PES'])
plt.show()
